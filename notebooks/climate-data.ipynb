# %%
import numpy as np 
import pandas as pd

# %%
month_of_interest = "01-2023"
url = "https://en.tutiempo.net/climate/{}/ws-419230.html"
url = url.format(month_of_interest)
url
# Out:
# 'https://en.tutiempo.net/climate/01-2023/ws-419230.html'

# %%
month_of_interest = ['01-2023', '02-2023','03-2023','04-2023', '05-2023', '06-2023', '07-2023', '08-2023']
url = "https://en.tutiempo.net/climate/{}/ws-419230.html"
for month in month_of_interest: 
    url = url.format(month)
    print(url)
# Out:
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html
# https://en.tutiempo.net/climate/01-2023/ws-419230.html

# %%
data_jan_2023 = pd.read_html("https://en.tutiempo.net/climate/01-2023/ws-419230.html", header = 0)

# %%
len(data_jan_2023)
# Out:
# 4

# %%
data_jan_2023 = data_jan_2023[2]

# %%
data_jan_2023
# Out:
#                           Day                          T  \
# 0                           1                       17.9
# 1                           2                       19.5
# 2                           3                       15.9
# 3                           4                        NaN
# 4                           5                        NaN
# 5                           6                        NaN
# 6                           7                       13.1
# 7                           8                       16.4
# 8                           9                       19.7
# 9                          10                        NaN
# 10                         11                        NaN
# 11                         12                        NaN
# 12                         13                       17.5
# 13                         14                       20.5
# 14                         15                       20.8
# ...
